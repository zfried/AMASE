# %%
import amase

# %%
amase.run_assignment(
    spectrum_path="/Users/zacharyfried/Desktop/test_amase_files/peppermint.txt",
    directory_path="/Users/zacharyfried/Desktop/test_amase_files",
    sigma_threshold=5.0,
    temperature=5.0,
    local_catalogs_enabled = True,
    local_directory = '/Users/zacharyfried/Desktop/desktop/database_catalogs/current_cfa_catalogs/cfa_catalogs',
    local_df = '/Users/zacharyfried/Desktop/desktop/database_catalogs/current_cfa_catalogs/local_smile_iso.csv',
    force_ignore_molecules = ['c1ccccc1', 'O=O'],
    consider_structure = False,
    manual_add_smiles = False
)
# Out:
# Hello! Beginning the assignment code now! If you run into any issues, please email zfried@mit.edu.
# Frequency linewidth: 0.21 MHz
#
# Number of peaks at 5.0 sigma significance in the spectrum: 322
#
# scraping local catalogs
#
# adding CC1(C)[C@H]2CCC(=O)[C@@H]1C2 to graph
# adding CC(=O)OC1CC(C)CCC1C(C)C to graph
# adding CC(C)[C@H]1CC[C@@H](C)CC1=O to graph
# adding CC1CCC(C(C)C)C(O)C1 to graph
# adding CC(C)=C1CC[C@@H](C)CC1=O to graph
# adding CC12CCC(CC1)C(C)(C)O2 to graph
# adding CC(C)[C@@H]1CC[C@@H](C)CC1=O to graph
# adding C=C1CCC2CC1C2(C)C to graph
# adding CC1=CCC2CC1C2(C)C to graph
#
# scraping cdms/jpl/lsd molecules
# adding c1cc2c3c(cccc3c1)CC2 to graph
# adding [C]#CC#CC#CC#CC#CC#C to graph
# adding c1ccc2c3ccccc3Cc2c1 to graph
# adding c1cc2cccc3c2c(c1)C=C3 to graph
# adding [C]=C=C=N to graph
# done with splatalogue query
#
# Ok, thanks! Now running the assignment algorithm.
#
# Catalog scraping took 1.75 minutes.
# ...
